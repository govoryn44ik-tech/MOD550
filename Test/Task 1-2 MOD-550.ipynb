# %% [markdown]
# 1. Task 1. Make a histogram from a 2d random distribution.

# %%
import matplotlib.pyplot as plt
import random
list_1 = [random.randint(1,15) for i in range(10)]
list_2 = [random.randint(20,60) for i in range(10)]

# %% [markdown]
# Sorry, i did not understand what diagram we need to make that is why i did more. I hope some of them is correct. To write this code i used a knowledge from different web-pages(googled, read and watched youtube lessons).

# %%
x = ['Movie','Math', 'Music', 'Test']
y = [15, 7, 2, 7]
plt.bar(x, y, label='Eksperiments')
plt.xlabel('Names of test')
plt.ylabel('T8')
plt.title('T8 value depending on brain activity')
plt.legend()
plt.show()

# %% [markdown]
# import matplotlib.pyplot as plt
# x = list_1
# y = list_2
# plt.hist2d(x,y, bins=15)
# plt.colorbar(label='Number of numbers')
# plt.title('Histogram')
# plt.show

# %%
n = 1000 
x = np.random.standard_normal(n) 
y = x* 5.0 + 3
fig = plt.subplots(figsize=(10,7))
plt.hist2d(x, y) 
plt.colorbar(label='Number of numbers')
plt.title("Simple 2D Histogram") 
cmap=plt.cm.nipy_spectral
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm

x = np.random.normal(0, 1, 10000)
y = np.random.normal(0, 1, 10000)

plt.hist2d(x, y, bins=(100, 100),cmap=cm.gist_rainbow)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Task 2 Make a 2d heat map from a 2d random

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.random((14,14))
plt.imshow(x, cmap='viridis', interpolation='nearest')
plt.title('Heatmap with random colors')
plt.show()

# %% [markdown]
# Task 3 Make a histogram for the source data you selected.
#
# For now i stuck with this part because i constracted my data and i am trying to understand how to work with and i try to find values and how to connect them with each other. First my dataset was trash(i think so). Second one is  a big. I am trying to understand how to compare different datasets with values that has the same names. I hope i will manage to figuire it out but it is not easy for me. I hope it exists some method in Python how to constract different datasets with the same names of values. I thought you saw my work with dataset in the same folder.(written 21.09).
