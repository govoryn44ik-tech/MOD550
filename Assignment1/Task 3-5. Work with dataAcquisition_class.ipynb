# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\govor\anaconda_projects\0d779c97-41ae-4743-8a08-902a13153742

# %%
from data_acqui import DataAcquisition

# %%
data_call = DataAcquisition(Year=None,Reading_score=None)

# %%
df_data = data_call.Opendata()
# Out:
#    Norway  Year  Reading score
# 0  Norway  2000            505
# 1  Norway  2003            500
# 2  Norway  2006            484
# 3  Norway  2009            503
# 4  Norway  2012            504

# %%
data_call.plot_histogram()

# %%
data_call.plot_pmf()
# Out:
#    Norway  Year  Reading score
# 0  Norway  2000            505
# 1  Norway  2003            500
# 2  Norway  2006            484
# 3  Norway  2009            503
# 4  Norway  2012            504

# %%
data_call.cumulative_sum()
# Out:
#    Norway  Year  Reading score
# 0  Norway  2000            505
# 1  Norway  2003            500
# 2  Norway  2006            484
# 3  Norway  2009            503
# 4  Norway  2012            504
#    Reading score  Cumulative Reading Score
# 0            505                       505
# 1            500                      1005
# 2            484                      1489
# 3            503                      1992
# 4            504                      2496
# 5            513                      3009
# 6            499                      3508
# 7            477                      3985
#    Norway  Year  Reading score  Cumulative Reading Score
# 0  Norway  2000            505                       505
# 1  Norway  2003            500                      1005
# 2  Norway  2006            484                      1489
# 3  Norway  2009            503                      1992
# 4  Norway  2012            504                      2496
# ...

# %% [markdown]
# To do the task i used information from different sources like google, youtube, geeksforgeeks, pandas documentation, github, matplotlib.org etc. I used AI to heplp me to find and fix errors in my code because it is difficalt often to see what you did wrong. I have got knowledge from different sources and analyzed it. I really enjoyed to work with data and different functions and classes.
